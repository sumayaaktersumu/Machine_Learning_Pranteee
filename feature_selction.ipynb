# %% [markdown]
# <a href="https://colab.research.google.com/github/sumayaaktersumu/Machine_Learning_Pranteee/blob/main/feature_selction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame({"A" : [1,2,4,1,2,4],
                     "B" : [4,5,6,7,8,9],
                     "C" : [0,0,0,0,0,0],
                     "D" : [1,1,1,1,1,1]})

# %%
data.head()
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  5  0  1
# 2  4  6  0  1
# 3  1  7  0  1
# 4  2  8  0  1

# %%
df = pd.read_csv("/content/drive/MyDrive/inflextionpoint/train.csv")

# %%
df.head()
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1   D
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1   D
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1   D
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1   B
#
#   s17 s18  s48 s52  ...        n7        n8        n9       n10       n11 n12  \
# 0   D   B    0   1  ... -9.126056  1.732291  3.698504  4.804517  1.544484   0
# 1   D   B    1   1  ... -9.098287  1.505885  6.791357  6.110416  1.712354   0
# 2   D   B    0   1  ... -9.234894  1.503828  4.109685  3.953226  1.804260   0
# 3   D   B    0   1  ... -9.378025  1.485863  7.265876  4.559419  1.537645   0
# 4   D   D    1   l  ... -9.261962  1.619210  3.737647  4.052003  1.637831   0
#
#    n13       n14 n15 label
# ...

# %%
df.tail()
# Out:
#                                                       id gender s11 s12  s13  \
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
#       s16 s17 s18  s48 s52  ...        n7        n8         n9        n10  \
# 28317   D   D   B    0   1  ... -8.651173  1.877460   3.637551  11.404942
# 28318   D   D   B    0   1  ... -8.833046  1.559138   4.247487   5.530054
# 28319   D   D   B    0   1  ... -9.233722  1.455911   2.900249   6.058681
# 28320   B   C   B    1   1  ... -8.748941  2.074394  10.673259  11.387646
# 28321   D   D   B    1   l  ... -9.280950  1.490478   3.569598   4.584967
#
#             n11 n12  n13       n14 n15 label
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28322 non-null  object
#  1   gender  28322 non-null  object
#  2   s11     28322 non-null  object
#  3   s12     28322 non-null  object
#  4   s13     28322 non-null  int64
#  5   s16     28322 non-null  object
#  6   s17     28322 non-null  object
#  7   s18     28322 non-null  object
#  8   s48     28322 non-null  int64
#  9   s52     28322 non-null  object
#  10  s53     28322 non-null  object
#  11  s54     2628 non-null   object
#  12  s55     3206 non-null   object
#  13  s56     0 non-null      float64
#  14  s57     0 non-null      float64
#  15  s58     28322 non-null  object
#  16  s59     0 non-null      float64
#  17  s69     28322 non-null  object
#  18  s70     28322 non-null  object
#  19  s71     28322 non-null  object
#  20  n1      28322 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 s13           s48  s56  s57  s59            n1            n2  \
# count  28322.000000  28322.000000  0.0  0.0  0.0  28322.000000  28322.000000
# mean       0.983123      0.433338  NaN  NaN  NaN     10.201863      1.600111
# std        0.128814      0.495545  NaN  NaN  NaN      4.414660      0.664985
# min        0.000000      0.000000  NaN  NaN  NaN      2.200736      0.311727
# 25%        1.000000      0.000000  NaN  NaN  NaN      6.592127      1.013540
# 50%        1.000000      0.000000  NaN  NaN  NaN      9.535961      1.462197
# 75%        1.000000      1.000000  NaN  NaN  NaN     14.432580      2.194510
# max        1.000000      1.000000  NaN  NaN  NaN     20.882733      3.137331
#
#                  n3            n4            n5  ...            n7  \
# count  28322.000000  28322.000000  28322.000000  ...  28322.000000
# mean       4.805099      5.080537    -32.641183  ...     -9.107429
# std        2.199282      2.276162      0.241453  ...      0.205200
# ...

# %%
df.shape
# Out:
# (28322, 36)

# %%
df.isnull()
# Out:
#           id  gender    s11    s12    s13    s16    s17    s18    s48    s52  \
# 0      False   False  False  False  False  False  False  False  False  False
# 1      False   False  False  False  False  False  False  False  False  False
# 2      False   False  False  False  False  False  False  False  False  False
# 3      False   False  False  False  False  False  False  False  False  False
# 4      False   False  False  False  False  False  False  False  False  False
# ...      ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 28317  False   False  False  False  False  False  False  False  False  False
# 28318  False   False  False  False  False  False  False  False  False  False
# 28319  False   False  False  False  False  False  False  False  False  False
# 28320  False   False  False  False  False  False  False  False  False  False
# 28321  False   False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# gender        0
# s11           0
# s12           0
# s13           0
# s16           0
# s17           0
# s18           0
# s48           0
# s52           0
# s53           0
# s54       25694
# s55       25116
# s56       28322
# s57       28322
# s58           0
# s59       28322
# s69           0
# s70           0
# s71           0
# n1            0
# n2            0
# n3            0
# n4            0
# n5            0
# n6            0
# n7            0
# n8            0
# n9            0
# n10           0
# n11           0
# n12           0
# n13           0
# n14           0
# n15           0
# label         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 135776

# %% [markdown]
# **Filling the null values**

# %%
df2 = df.fillna(value= 0)
df2
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 135776

# %%
df3 = df.fillna(value= 5)
df3
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %% [markdown]
# ## **filling null value with a previous value**

# %%
df4 = df.fillna(method= 'pad')
df4
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
df4.isnull().sum()
# Out:
# id            0
# gender        0
# s11           0
# s12           0
# s13           0
# s16           0
# s17           0
# s18           0
# s48           0
# s52           0
# s53           0
# s54          11
# s55           0
# s56       28322
# s57       28322
# s58           0
# s59       28322
# s69           0
# s70           0
# s71           0
# n1            0
# n2            0
# n3            0
# n4            0
# n5            0
# n6            0
# n7            0
# n8            0
# n9            0
# n10           0
# n11           0
# n12           0
# n13           0
# n14           0
# n15           0
# label         0
# dtype: int64

# %%
df
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
#filling null values with the next values
df5 = df.fillna(method= 'bfill')
df5
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
df6 = df.fillna(method= 'pad', axis = 1)
df6
# Out:
#                                                       id gender s11 s12 s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N   1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y   1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y   1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y   1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y   1
# ...                                                  ...    ...  ..  ..  ..
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y   1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y   1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y   1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y   1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y   1
#
# ...

# %%
df6 = df.fillna(method= 'bfill', axis = 1)
df6
# Out:
#                                                       id gender s11 s12 s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N   1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y   1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y   1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y   1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y   1
# ...                                                  ...    ...  ..  ..  ..
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y   1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y   1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y   1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y   1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y   1
#
# ...

# %%
df
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
#filling diffrent value in null in diffrent coloumns
df8 = df.fillna({'s56' : 'abcd',
                 's59' : 'defg'})
df8
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
#filling null values with the mean of coloumn
df9 = df.fillna(value=df['s57'].mean())
df9
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
##dropna()

# %%
df10 = df.dropna()
df10
# Out:
# Empty DataFrame
# Columns: [id, gender, s11, s12, s13, s16, s17, s18, s48, s52, s53, s54, s55, s56, s57, s58, s59, s69, s70, s71, n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12, n13, n14, n15, label]
# Index: []
#
# [0 rows x 36 columns]

# %%
df11 = df.dropna(how = 'all')
df11
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
df11 = df.dropna(how = 'any')
df11
# Out:
# Empty DataFrame
# Columns: [id, gender, s11, s12, s13, s16, s17, s18, s48, s52, s53, s54, s55, s56, s57, s58, s59, s69, s70, s71, n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12, n13, n14, n15, label]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# ##replace

# %%
df12 = df.replace(to_replace= np.nan,value = 12345)
df12
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
df13 = df.replace(to_replace = 3.0 ,value = 5.0)
df13
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %% [markdown]
# ##interpolate

# %%
df['s57'] =df['s57'].interpolate(method= 'linear', limit_direction= 'forward')
df
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...
